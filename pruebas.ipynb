# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
print(os.listdir("MAFood121"))

import cv2
import torch
import torch.utils.data as data
from torch.autograd import Variable
import torch.nn as nn
from torchvision import datasets, transforms
from glob import glob
import matplotlib.pyplot as plt
import torchvision.models as models
from torchvision.models import ResNet50_Weights

use_cuda = True
device = torch.device("cuda" if use_cuda else "cpu")
torch.manual_seed(42) # try and make the results more reproducible
BASE_PATH = 'MAFood121/'

epochs = 35
batch_size = 64
MICRO_DATA = True # very small subset (just 3 groups)
SAMPLE_TRAINING = False # make train set smaller for faster iteration
IMG_SIZE = (384, 384) # Try to change the model to U-net to avoid the resizing

#Classes of dishes
f = open(BASE_PATH + '/annotations/dishes.txt', "r")
classes = f.read().split('\n')
f.close()
print("***** classes = dishes.txt: ***** " + str(classes))
print("#######################################################################################")

#Ingredients for each class
f = open(BASE_PATH + '/annotations/foodgroups.txt', "r")
ingredients = f.read().split('\n')
f.close()
print("***** ingredients = foodgroups.txt: ***** " + str(classes))
print("#######################################################################################")

#Base Ingredients
f = open(BASE_PATH + '/annotations/baseIngredients.txt', "r")
base_ing = f.read().strip().split(', ')
f.close()
print("***** base_ing = baseIngredients.txt: ***** " + str(classes))
print("#######################################################################################")

#Recovery of annotations ML
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()

#train
f = open(BASE_PATH + '/annotations/train.txt', "r")
train_images = f.read().split('\n')
f.close()
f = open(BASE_PATH + '/annotations/train_lbls_ff.txt', "r")
train_labels = f.read().split('\n')
f.close()

#val
f = open(BASE_PATH + '/annotations/val.txt', "r")
val_images = f.read().split('\n')
f.close()
f = open(BASE_PATH + '/annotations/val_lbls_ff.txt', "r")
val_labels = f.read().split('\n')
f.close()

#test
f = open(BASE_PATH + '/annotations/test.txt', "r")
test_images = f.read().split('\n')
f.close()
f = open(BASE_PATH + '/annotations/test_lbls_ff.txt', "r")
test_labels = f.read().split('\n')
f.close()

#Recovery of annotations SL
#train
f = open(BASE_PATH + '/annotations/train.txt', "r")
train_imagessl = f.read().split('\n')
f.close()
f = open(BASE_PATH + '/annotations/train_lbls_d.txt', "r")
train_labelssl = f.read().split('\n')
f.close()

#val
f = open(BASE_PATH + '/annotations/val.txt', "r")
val_imagessl = f.read().split('\n')
f.close()
f = open(BASE_PATH + '/annotations/val_lbls_d.txt', "r")
val_labelssl = f.read().split('\n')
f.close()

#test
f = open(BASE_PATH + '/annotations/test.txt', "r")
test_imagessl = f.read().split('\n')
f.close()
f = open(BASE_PATH + '/annotations/test_lbls_d.txt', "r")
test_labelssl = f.read().split('\n')
f.close()

# Single-Label
train_images_sl = ["MAFood121/images/" + s for s in train_imagessl]
train_df_sl = pd.DataFrame({'path': train_images_sl, 'class_id': train_labelssl})

val_images_sl = ["MAFood121/images/" + s for s in val_imagessl]
val_df_sl = pd.DataFrame({'path': val_images_sl, 'class_id': val_labelssl})

test_images_sl = ["MAFood121/images/" + s for s in test_imagessl]
test_df_sl = pd.DataFrame({'path': test_images_sl, 'class_id': test_labelssl})

# Multi-label
train_images_ml = ["MAFood121/images/" + s for s in train_images]
train_df_ml = pd.DataFrame({'path': train_images_ml, 'class_id': train_labels})

val_images_ml = ["MAFood121/images/" + s for s in val_images]
val_df_ml = pd.DataFrame({'path': val_images_ml, 'class_id': val_labels})

test_images_ml = ["MAFood121/images/" + s for s in test_images]
test_df_ml = pd.DataFrame({'path': test_images_ml, 'class_id': test_labels})

# Train images
train_img_df = pd.concat([train_df_sl, train_df_ml])
val_img_df = pd.concat([val_df_sl, val_df_ml])
test_img_df = pd.concat([test_df_sl, test_df_ml])

train_img_df = train_img_df.sample(frac=1).reset_index(drop=True)
val_img_df = val_img_df.sample(frac=1).reset_index(drop=True)
test_img_df = test_img_df.sample(frac=1).reset_index(drop=True)

train_img_df['class_name'] = train_img_df['path'].map(lambda x: os.path.split(os.path.dirname(x))[-1])
print(train_img_df)
print("-------------------------------------------------------------------------------------------------")

val_img_df['class_name'] = val_img_df['path'].map(lambda x: os.path.split(os.path.dirname(x))[-1])
print(val_img_df)
print("-------------------------------------------------------------------------------------------------")

test_img_df['class_name'] = test_img_df['path'].map(lambda x: os.path.split(os.path.dirname(x))[-1])
print(test_img_df)

#Dataframe for train images
import glob

train_ingredients = []
train_classid = []

# busca ambos archivos en el directorio de anotaciones
for file_path in glob.glob(BASE_PATH + '/annotations/train_lbls_*.txt'):
    with open(file_path) as f1:
        for line in f1:
            idx_ingredients = []
            classid = int(line)
            train_classid.append(classid)
            for ing in ingredients[classid].strip().split(","):
                idx_ingredients.append(str(base_ing.index(ing)))
            train_ingredients.append(idx_ingredients)

df_train = pd.DataFrame(mlb.fit_transform(train_ingredients), columns=mlb.classes_) #binary encode ingredients
df_train["path"] = train_img_df['path']
df_train["class_id"] = train_classid 
food_dict_train = df_train


new_data = []
for index, row in train_img_df.iterrows():
    food = row["class_name"]
    path = row["path"]
    class_id = row["class_id"]
    
    binary_encod = food_dict_train.loc[food_dict_train["path"] == path]
    new_data.append(np.array(binary_encod)[0])

col_names = list(binary_encod.columns.values)
train_df = pd.DataFrame(new_data, columns = col_names)

#Dataframe for val images

val_ingredients = []
val_classid = []

# busca ambos archivos en el directorio de anotaciones
for file_path in glob.glob(BASE_PATH + '/annotations/val_lbls_*.txt'):
    with open(file_path) as f1:
        for line in f1:
            idx_ingredients = []
            classid = int(line)
            val_classid.append(classid)
            for ing in ingredients[classid].strip().split(","):
                idx_ingredients.append(str(base_ing.index(ing)))
            val_ingredients.append(idx_ingredients)

df_val = pd.DataFrame(mlb.fit_transform(val_ingredients), columns=mlb.classes_) #binary encode ingredients
df_val["path"] = val_img_df['path']
df_val["class_id"] = val_classid 
food_dict_val = df_val


new_data = []
for index, row in val_img_df.iterrows():
    food = row["class_name"]
    path = row["path"]
    class_id = row["class_id"]
    
    binary_encod = food_dict_val.loc[food_dict_val["path"] == path]
    new_data.append(np.array(binary_encod)[0])

col_names = list(binary_encod.columns.values)
val_df = pd.DataFrame(new_data, columns = col_names)

#Dataframe for test images

test_ingredients = []
test_classid = []

# busca ambos archivos en el directorio de anotaciones
for file_path in glob.glob(BASE_PATH + '/annotations/test_lbls_*.txt'):
    with open(file_path) as f1:
        for line in f1:
            idx_ingredients = []
            classid = int(line)
            test_classid.append(classid)
            for ing in ingredients[classid].strip().split(","):
                idx_ingredients.append(str(ingredients.index(ing)))
            test_ingredients.append(idx_ingredients)

df_test = pd.DataFrame(mlb.fit_transform(test_ingredients), columns=mlb.classes_) #binary encode ingredients
df_test["path"] = test_img_df['path']
df_test["class_id"] = test_classid 
food_dict_test = df_test


new_data = []
for index, row in test_img_df.iterrows():
    food = row["class_name"]
    path = row["path"]
    class_id = row["class_id"]
    
    binary_encod = food_dict_test.loc[food_dict_test["path"] == path]
    new_data.append(np.array(binary_encod)[0])

col_names = list(binary_encod.columns.values)
test_df = pd.DataFrame(new_data, columns = col_names)

train_df.to_hdf('train_df.h5','df',mode='w',format='table',data_columns=True)
val_df.to_hdf('val_df.h5','df',mode='w',format='table',data_columns=True)
test_df.to_hdf('test_df.h5','df',mode='w',format='table',data_columns=True)
# Out:
# ['annotations', 'images']
# ***** classes = dishes.txt: ***** ['d_artichoke_bottoms_in_olive_oil', 'd_baby_back_ribs', 'd_banh_mi', 'd_banh_xeo', 'd_beef_bourguignon', 'd_beef_carpaccio', 'd_beef_in_oyster_sauce', 'd_biryani', 'd_blanquette_de_veau', 'd_borek', 'd_breakfast_burrito', 'd_bruschetta', 'd_bun_cha', 'd_butter_chicken', 'd_caesar_salad', 'd_cao_lau', 'd_caprese_salad', 'd_cha_ca', 'd_charcoal-boiled_pork_neck', 'd_chicken_quesadilla', 'd_chilaquiles', 'd_chiles_en_nogada', 'd_chole', 'd_chow_mein', 'd_cig_kofte', 'd_clam_chowder', 'd_club_sandwich', 'd_coconut_milk-flavored_crepes_with_shrimp_and_beef', 'd_coconut_milk_soup', 'd_com_tam', 'd_confit_de_canard', 'd_coq_au_vin', 'd_croque_madame', 'd_eggs_benedict', 'd_enchiladas', 'd_foie_gras', 'd_french_onion_soup', 'd_fried_mussel_pancakes', 'd_fried_pork_in_scoop', 'd_gnocchi', 'd_goya_champuru', 'd_greek_salad', 'd_green_curry', 'd_guacamole', 'd_gyro', 'd_hamburger', 'd_hamsi', 'd_hot_and_sour_fish_and_vegetable_ragout', 'd_hot_and_sour_soup', 'd_hue_beef_rice_vermicelli_soup', 'd_huevos_rancheros', 'd_hunkar_begendi', 'd_icli_kofte', 'd_ispanak', 'd_kaali_daal', 'd_kebap', 'd_khao_soi', 'd_kisir', 'd_kolokythokeftedes', 'd_kung_pao_chicken', 'd_lasagna', 'd_lobster_bisque', 'd_lobster_roll_sandwich', 'd_malai_kofta', 'd_manti', 'd_melitzanosalata', 'd_minestrone', 'd_miso_soup', 'd_moussaka', 'd_mushroom_risotto', 'd_naan', 'd_nachos', 'd_noodles_with_fish_curry', 'd_okinawa_soba', 'd_omelette', 'd_onion_rings', 'd_pad_thai', 'd_palak_paneer', 'd_paneer_tikka', 'd_papdi_chaat', 'd_pastitsio', 'd_peking_duck', 'd_pho', 'd_pizza', 'd_pozole', 'd_prime_rib', 'd_ramen', 'd_ratatouille', 'd_ravioli', 'd_rogan_josh', 'd_saganaki', 'd_salade_nicoise', 'd_sarma', 'd_sashimi', 'd_shrimp_and_grits', 'd_soba_noodle', 'd_souvlaki', 'd_spaghetti_bolognese', 'd_spaghetti_carbonara', 'd_spanakopita', 'd_spring_rolls', 'd_steak', 'd_steamed_rice_roll', 'd_stewed_pork_leg', 'd_sukiyaki', 'd_sushi', 'd_tacos', 'd_takoyaki', 'd_tandoori_chicken', 'd_tempura', 'd_thai_papaya_salad', 'd_tomatokeftedes', 'd_tostadas', 'd_twice_cooked_pork', 'd_udon_noodle', 'd_vermicelli_noodles_with_snails', 'd_winter_melon_soup', 'd_xiao_long_bao', 'd_yellow_curry', 'd_yemista', 'd_zha_jiang_mian', '']
# #######################################################################################
# ***** ingredients = foodgroups.txt: ***** ['d_artichoke_bottoms_in_olive_oil', 'd_baby_back_ribs', 'd_banh_mi', 'd_banh_xeo', 'd_beef_bourguignon', 'd_beef_carpaccio', 'd_beef_in_oyster_sauce', 'd_biryani', 'd_blanquette_de_veau', 'd_borek', 'd_breakfast_burrito', 'd_bruschetta', 'd_bun_cha', 'd_butter_chicken', 'd_caesar_salad', 'd_cao_lau', 'd_caprese_salad', 'd_cha_ca', 'd_charcoal-boiled_pork_neck', 'd_chicken_quesadilla', 'd_chilaquiles', 'd_chiles_en_nogada', 'd_chole', 'd_chow_mein', 'd_cig_kofte', 'd_clam_chowder', 'd_club_sandwich', 'd_coconut_milk-flavored_crepes_with_shrimp_and_beef', 'd_coconut_milk_soup', 'd_com_tam', 'd_confit_de_canard', 'd_coq_au_vin', 'd_croque_madame', 'd_eggs_benedict', 'd_enchiladas', 'd_foie_gras', 'd_french_onion_soup', 'd_fried_mussel_pancakes', 'd_fried_pork_in_scoop', 'd_gnocchi', 'd_goya_champuru', 'd_greek_salad', 'd_green_curry', 'd_guacamole', 'd_gyro', 'd_hamburger', 'd_hamsi', 'd_hot_and_sour_fish_and_vegetable_ragout', 'd_hot_and_sour_soup', 'd_hue_beef_rice_vermicelli_soup', 'd_huevos_rancheros', 'd_hunkar_begendi', 'd_icli_kofte', 'd_ispanak', 'd_kaali_daal', 'd_kebap', 'd_khao_soi', 'd_kisir', 'd_kolokythokeftedes', 'd_kung_pao_chicken', 'd_lasagna', 'd_lobster_bisque', 'd_lobster_roll_sandwich', 'd_malai_kofta', 'd_manti', 'd_melitzanosalata', 'd_minestrone', 'd_miso_soup', 'd_moussaka', 'd_mushroom_risotto', 'd_naan', 'd_nachos', 'd_noodles_with_fish_curry', 'd_okinawa_soba', 'd_omelette', 'd_onion_rings', 'd_pad_thai', 'd_palak_paneer', 'd_paneer_tikka', 'd_papdi_chaat', 'd_pastitsio', 'd_peking_duck', 'd_pho', 'd_pizza', 'd_pozole', 'd_prime_rib', 'd_ramen', 'd_ratatouille', 'd_ravioli', 'd_rogan_josh', 'd_saganaki', 'd_salade_nicoise', 'd_sarma', 'd_sashimi', 'd_shrimp_and_grits', 'd_soba_noodle', 'd_souvlaki', 'd_spaghetti_bolognese', 'd_spaghetti_carbonara', 'd_spanakopita', 'd_spring_rolls', 'd_steak', 'd_steamed_rice_roll', 'd_stewed_pork_leg', 'd_sukiyaki', 'd_sushi', 'd_tacos', 'd_takoyaki', 'd_tandoori_chicken', 'd_tempura', 'd_thai_papaya_salad', 'd_tomatokeftedes', 'd_tostadas', 'd_twice_cooked_pork', 'd_udon_noodle', 'd_vermicelli_noodles_with_snails', 'd_winter_melon_soup', 'd_xiao_long_bao', 'd_yellow_curry', 'd_yemista', 'd_zha_jiang_mian', '']
# #######################################################################################
# ***** base_ing = baseIngredients.txt: ***** ['d_artichoke_bottoms_in_olive_oil', 'd_baby_back_ribs', 'd_banh_mi', 'd_banh_xeo', 'd_beef_bourguignon', 'd_beef_carpaccio', 'd_beef_in_oyster_sauce', 'd_biryani', 'd_blanquette_de_veau', 'd_borek', 'd_breakfast_burrito', 'd_bruschetta', 'd_bun_cha', 'd_butter_chicken', 'd_caesar_salad', 'd_cao_lau', 'd_caprese_salad', 'd_cha_ca', 'd_charcoal-boiled_pork_neck', 'd_chicken_quesadilla', 'd_chilaquiles', 'd_chiles_en_nogada', 'd_chole', 'd_chow_mein', 'd_cig_kofte', 'd_clam_chowder', 'd_club_sandwich', 'd_coconut_milk-flavored_crepes_with_shrimp_and_beef', 'd_coconut_milk_soup', 'd_com_tam', 'd_confit_de_canard', 'd_coq_au_vin', 'd_croque_madame', 'd_eggs_benedict', 'd_enchiladas', 'd_foie_gras', 'd_french_onion_soup', 'd_fried_mussel_pancakes', 'd_fried_pork_in_scoop', 'd_gnocchi', 'd_goya_champuru', 'd_greek_salad', 'd_green_curry', 'd_guacamole', 'd_gyro', 'd_hamburger', 'd_hamsi', 'd_hot_and_sour_fish_and_vegetable_ragout', 'd_hot_and_sour_soup', 'd_hue_beef_rice_vermicelli_soup', 'd_huevos_rancheros', 'd_hunkar_begendi', 'd_icli_kofte', 'd_ispanak', 'd_kaali_daal', 'd_kebap', 'd_khao_soi', 'd_kisir', 'd_kolokythokeftedes', 'd_kung_pao_chicken', 'd_lasagna', 'd_lobster_bisque', 'd_lobster_roll_sandwich', 'd_malai_kofta', 'd_manti', 'd_melitzanosalata', 'd_minestrone', 'd_miso_soup', 'd_moussaka', 'd_mushroom_risotto', 'd_naan', 'd_nachos', 'd_noodles_with_fish_curry', 'd_okinawa_soba', 'd_omelette', 'd_onion_rings', 'd_pad_thai', 'd_palak_paneer', 'd_paneer_tikka', 'd_papdi_chaat', 'd_pastitsio', 'd_peking_duck', 'd_pho', 'd_pizza', 'd_pozole', 'd_prime_rib', 'd_ramen', 'd_ratatouille', 'd_ravioli', 'd_rogan_josh', 'd_saganaki', 'd_salade_nicoise', 'd_sarma', 'd_sashimi', 'd_shrimp_and_grits', 'd_soba_noodle', 'd_souvlaki', 'd_spaghetti_bolognese', 'd_spaghetti_carbonara', 'd_spanakopita', 'd_spring_rolls', 'd_steak', 'd_steamed_rice_roll', 'd_stewed_pork_leg', 'd_sukiyaki', 'd_sushi', 'd_tacos', 'd_takoyaki', 'd_tandoori_chicken', 'd_tempura', 'd_thai_papaya_salad', 'd_tomatokeftedes', 'd_tostadas', 'd_twice_cooked_pork', 'd_udon_noodle', 'd_vermicelli_noodles_with_snails', 'd_winter_melon_soup', 'd_xiao_long_bao', 'd_yellow_curry', 'd_yemista', 'd_zha_jiang_mian', '']
# #######################################################################################
#                                                     path class_id  \
# 0                    MAFood121/images/sashimi/665207.jpg      103
# 1              MAFood121/images/croque_madame/497428.jpg       41
# 2           MAFood121/images/twice_cooked_pork/82644.jpg      113
# 3                   MAFood121/images/lasagna/1145339.jpg      117
# 4                   MAFood121/images/enchiladas/14_1.jpg       34
# ...                                                  ...      ...
# 30593                      MAFood121/images/borek/23.jpg        9
# 30594                     MAFood121/images/gyro/56_1.jpg        2
# 30595  MAFood121/images/artichoke_bottoms_in_olive_oi...       37
# 30596               MAFood121/images/lasagna/2111969.jpg       83
# 30597                  MAFood121/images/yemista/23_2.jpg      119
#
#                            class_name
# 0                             sashimi
# 1                       croque_madame
# 2                   twice_cooked_pork
# 3                             lasagna
# 4                          enchiladas
# ...                               ...
# 30593                           borek
# 30594                            gyro
# 30595  artichoke_bottoms_in_olive_oil
# 30596                         lasagna
# 30597                         yemista
#
# [30598 rows x 3 columns]
# -------------------------------------------------------------------------------------------------
#                                                    path class_id  \
# 0              MAFood121/images/onion_rings/1752491.jpg       75
# 1                  MAFood121/images/sashimi/3603470.jpg       93
# 2                 MAFood121/images/udon_noodle/1981.jpg      114
# 3             MAFood121/images/croque_madame/231385.jpg       32
# 4              MAFood121/images/onion_rings/2538482.jpg       75
# ...                                                 ...      ...
# 5397   MAFood121/images/beef_in_oyster_sauce/134481.jpg       37
# 5398   MAFood121/images/spaghetti_carbonara/3053550.jpg      117
# 5399        MAFood121/images/baby_back_ribs/2535607.jpg      176
# 5400  MAFood121/images/artichoke_bottoms_in_olive_oi...        0
# 5401      MAFood121/images/winter_melon_soup/336856.jpg      126
#
#                           class_name
# 0                        onion_rings
# 1                            sashimi
# 2                        udon_noodle
# 3                      croque_madame
# 4                        onion_rings
# ...                              ...
# 5397            beef_in_oyster_sauce
# 5398             spaghetti_carbonara
# 5399                  baby_back_ribs
# 5400  artichoke_bottoms_in_olive_oil
# 5401               winter_melon_soup
#
# [5402 rows x 3 columns]
# -------------------------------------------------------------------------------------------------
#                                                   path class_id  \
# 0        MAFood121/images/hot_and_sour_soup/406167.jpg      157
# 1        MAFood121/images/shrimp_and_grits/3050912.jpg       94
# 2       MAFood121/images/french_onion_soup/1940493.jpg      107
# 3                    MAFood121/images/ramen/453058.jpg       21
# 4                   MAFood121/images/tacos/1638510.jpg      106
# ...                                                ...      ...
# 6351        MAFood121/images/eggs_benedict/1412040.jpg       46
# 6352               MAFood121/images/icli_kofte/490.jpg       52
# 6353                MAFood121/images/souvlaki/95_2.jpg        2
# 6354  MAFood121/images/spaghetti_carbonara/1599889.jpg       98
# 6355       MAFood121/images/beef_carpaccio/2855917.jpg       37
#
#                class_name
# 0       hot_and_sour_soup
# 1        shrimp_and_grits
# 2       french_onion_soup
# 3                   ramen
# 4                   tacos
# ...                   ...
# 6351        eggs_benedict
# 6352           icli_kofte
# 6353             souvlaki
# 6354  spaghetti_carbonara
# 6355       beef_carpaccio
#
# [6356 rows x 3 columns]
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '0'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '1'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '3'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '4'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '5'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '6'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '7'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '8'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '9'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '0_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '0_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '0_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '1_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '1_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '1_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '2_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '2_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '2_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '3_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '3_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '3_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '4_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '4_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '4_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '5_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '5_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '5_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '6_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '6_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '6_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '7_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '7_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '7_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '8_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '8_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '8_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '9_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '9_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '9_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '0'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '1'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '3'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '4'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '5'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '6'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '7'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '8'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '9'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '0_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '0_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '0_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '1_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '1_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '1_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '2_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '2_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '2_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '3_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '3_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '3_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '4_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '4_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '4_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '5_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '5_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '5_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '6_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '6_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '6_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '7_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '7_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '7_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '8_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '8_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '8_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '9_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '9_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '9_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '103'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '107'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '173'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '176'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '22'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '45'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '49'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '7'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '83'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '86'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '103_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '103_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '103_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '107_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '107_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '107_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '173_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '173_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '173_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '176_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '176_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '176_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '22_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '22_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '22_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '45_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '45_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '45_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '49_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '49_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '49_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '7_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '7_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '7_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '83_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '83_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '83_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '86_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '86_meta'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\danie\anaconda3\envs\pytorch\lib\site-packages\tables\attributeset.py:459: NaturalNameWarning: object name is not a valid Python identifier: '86_dtype'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)

# %%
import pandas as pd
from torch.utils.data import DataLoader, Dataset

# Load data from .h5 files
train_df = pd.read_hdf('train_df.h5', 'df')
val_df = pd.read_hdf('val_df.h5', 'df')
test_df = pd.read_hdf('test_df.h5', 'df')

epochs = 20
batch_size = 16
SMALL_DATA = False
IMG_SIZE = (384, 384)

if SMALL_DATA:
    train_df = train_df[:128]
    val_df = test_df[:128]
    test_df = test_df[:128]

col_names = list(train_df.columns.values)

ing_names = col_names[:-3]
targets = ing_names

class CustomDataset(Dataset):
    def __init__(target, df):
        target.df = df

    def __len__(target):
        return len(target.df)

    def __getitem__(target, idx):
        x = target.df.iloc[idx]['image']
        sl_y = target.df.iloc[idx]['SL']
        ml_y = target.df.iloc[idx]['ML']
        return x, sl_y, ml_y

# Define batch size
batch_size = 32

# Create DataLoader objects for training, validation, and testing sets
train_dataset = CustomDataset(train_df)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = CustomDataset(val_df)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

test_dataset = CustomDataset(test_df)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# ResNet50 Model
from torchvision import models
from torch import nn

resnet = models.resnet50(weights=None)
# Disable grad for all conv layers
for param in resnet.parameters():
    param.requires_grad = False

# Add two heads
n_features = resnet.fc.in_features
resnet.fc = nn.Identity()
head_sl = nn.Sequential(
    nn.Linear(n_features, 512),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.2),
    nn.Linear(512, len(classes))
)
head_ml = nn.Sequential(
    nn.Linear(n_features, 512),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.2),
    nn.Linear(512, len(ingredients)),
    nn.Sigmoid()
)  
        
# Connect two heads
class FoodModel(nn.Module):
    def __init__(target, base_model, head_sl, head_ml):
        super().__init__()
        target.base_model = base_model
        target.head_sl = head_sl
        target.head_ml = head_ml

    def forward(target, x):
        x = target.base_model(x)
        sl = target.head_sl(x)
        ml = target.head_ml(x)
        return sl, ml

model = FoodModel(resnet, head_sl, head_ml)
model.to(device)

# Define Loss
sl_loss_fn = nn.CrossEntropyLoss()
ml_loss_fn = nn.BCELoss()

# Define Optimizer
optimizer = torch.optim.Adam(model.parameters())

# Define function to calculate loss and train model
def train_step(model, optimizer, sl_loss_fn, ml_loss_fn, data, device):
    # Retrieve data
    x, sl_y, ml_y = data
    # Convert to device
    x = x.to(device)
    sl_y = sl_y.to(device)
    ml_y = ml_y.to(device)
    # Zero out gradients
    optimizer.zero_grad()
    # Forward pass
    sl_preds, ml_preds = model(x)
    # Calculate losses
    sl_loss = sl_loss_fn(sl_preds, sl_y)
    ml_loss = ml_loss_fn(ml_preds, ml_y)
    loss = sl_loss + ml_loss
    # Backward pass
    loss.backward()
    # Step optimizer
    optimizer.step()
    # Return losses
    return sl_loss.item(), ml_loss.item()

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Load a test image
img_path = '82439.jpg'
img = Image.open(img_path).convert('RGB')
plt.imshow(img)

# Resize image and convert to tensor
transform = transforms.Compose([transforms.Resize(IMG_SIZE), transforms.ToTensor()])
img = transform(img)
img = img.unsqueeze(0)

# Get model predictions
model.eval()
with torch.no_grad():
    sl_preds, ml_preds = model(img.to(device))

    # Show prediction percentages
    print("Softmax Prediction:")
    for i, sl_pred in enumerate(sl_preds[0]):
        pred_pct = round(max(min(sl_pred.item(), 1), 0), 2)
        print(f"{classes[i]}: {pred_pct}")

    print("Sigmoid Prediction:")
    for i, ml_pred in enumerate(ml_preds[0]):
        pred_pct = round(max(min(ml_pred.item() / 1, 1), 0), 2)
        print(f"{ingredients[i]}: {pred_pct}")

    # Convert predictions to numpy.ndarray and move to CPU
    sl_preds = sl_preds.cpu().numpy()
    ml_preds = ml_preds.cpu().numpy()

# Plot prediction results
sl_preds = sl_preds.squeeze()
plt.figure(figsize=(10, 5))
plt.bar(classes, sl_preds)
plt.title('Softmax Prediction')
plt.xticks(rotation=90) # Rotate x-axis labels to vertical
plt.xlabel('Food Category')
plt.ylabel('Probability')
plt.ylim(0, 1)  # set y-axis limits to 0-1
plt.show()

ml_preds = ml_preds.squeeze()
plt.figure(figsize=(10, 5))
plt.bar(ingredients, ml_preds)
plt.title('Sigmoid Prediction')
plt.xticks(rotation=90) # Rotate x-axis labels to vertical
plt.xlabel('Ingredient')
plt.ylabel('Probability')
plt.ylim(0, 1)  # set y-axis limits to 0-1
plt.show()
# Out:
# Softmax Prediction:
# d_artichoke_bottoms_in_olive_oil: 0.18
# d_baby_back_ribs: 1
# d_banh_mi: 0
# d_banh_xeo: 1
# d_beef_bourguignon: 0
# d_beef_carpaccio: 0
# d_beef_in_oyster_sauce: 1
# d_biryani: 0.99
# d_blanquette_de_veau: 0.56
# d_borek: 1
# d_breakfast_burrito: 0
# d_bruschetta: 0
# d_bun_cha: 0
# d_butter_chicken: 0
# d_caesar_salad: 1
# d_cao_lau: 1
# d_caprese_salad: 0
# d_cha_ca: 1
# d_charcoal-boiled_pork_neck: 0
# d_chicken_quesadilla: 1
# d_chilaquiles: 1
# d_chiles_en_nogada: 0
# d_chole: 0
# d_chow_mein: 0.73
# d_cig_kofte: 0
# d_clam_chowder: 0.57
# d_club_sandwich: 0.81
# d_coconut_milk-flavored_crepes_with_shrimp_and_beef: 0
# d_coconut_milk_soup: 1
# d_com_tam: 0
# d_confit_de_canard: 0
# d_coq_au_vin: 0
# d_croque_madame: 0
# d_eggs_benedict: 1
# d_enchiladas: 1
# d_foie_gras: 0
# d_french_onion_soup: 0
# d_fried_mussel_pancakes: 1
# d_fried_pork_in_scoop: 0
# d_gnocchi: 0
# d_goya_champuru: 1
# d_greek_salad: 0
# d_green_curry: 0
# d_guacamole: 0.92
# d_gyro: 1
# d_hamburger: 0
# d_hamsi: 0
# d_hot_and_sour_fish_and_vegetable_ragout: 1
# d_hot_and_sour_soup: 0.35
# d_hue_beef_rice_vermicelli_soup: 0
# d_huevos_rancheros: 0
# d_hunkar_begendi: 1
# d_icli_kofte: 0
# d_ispanak: 0
# d_kaali_daal: 0.77
# d_kebap: 1
# d_khao_soi: 0.86
# d_kisir: 0
# d_kolokythokeftedes: 1
# d_kung_pao_chicken: 0
# d_lasagna: 0
# d_lobster_bisque: 0
# d_lobster_roll_sandwich: 1
# d_malai_kofta: 0.72
# d_manti: 0
# d_melitzanosalata: 0
# d_minestrone: 0
# d_miso_soup: 0
# d_moussaka: 1
# d_mushroom_risotto: 0
# d_naan: 0
# d_nachos: 0
# d_noodles_with_fish_curry: 0
# d_okinawa_soba: 0
# d_omelette: 0.15
# d_onion_rings: 0
# d_pad_thai: 0
# d_palak_paneer: 1
# d_paneer_tikka: 1
# d_papdi_chaat: 0
# d_pastitsio: 1
# d_peking_duck: 1
# d_pho: 0
# d_pizza: 1
# d_pozole: 0
# d_prime_rib: 1
# d_ramen: 0
# d_ratatouille: 0
# d_ravioli: 0
# d_rogan_josh: 1
# d_saganaki: 1
# d_salade_nicoise: 1
# d_sarma: 1
# d_sashimi: 1
# d_shrimp_and_grits: 0.35
# d_soba_noodle: 0
# d_souvlaki: 0
# d_spaghetti_bolognese: 0.67
# d_spaghetti_carbonara: 0
# d_spanakopita: 1
# d_spring_rolls: 0
# d_steak: 0.47
# d_steamed_rice_roll: 0
# d_stewed_pork_leg: 0
# d_sukiyaki: 1
# d_sushi: 0
# d_tacos: 0
# d_takoyaki: 1
# d_tandoori_chicken: 0.89
# d_tempura: 0.43
# d_thai_papaya_salad: 1
# d_tomatokeftedes: 0
# d_tostadas: 0
# d_twice_cooked_pork: 0
# d_udon_noodle: 1
# d_vermicelli_noodles_with_snails: 0
# d_winter_melon_soup: 0
# d_xiao_long_bao: 1
# d_yellow_curry: 0
# d_yemista: 0
# d_zha_jiang_mian: 1
# : 1
# Sigmoid Prediction:
# ff_egg,ff_fried_food,ff_vegetable: 0.13
# ff_egg,ff_seafood,ff_vegetable: 0.99
# ff_bread,ff_meat,ff_vegetable: 0.53
# ff_rice,ff_seafood,ff_soup,ff_vegetable: 0.4
# ff_fried_food,ff_soup: 0.42
# ff_fried_food,ff_rice,ff_seafood,ff_vegetable: 0.08
# ff_bread,ff_egg,ff_fried_food: 0.59
# ff_egg: 0.31
# ff_egg,ff_meat,ff_noodles/pasta,ff_rice,ff_vegetable: 0.66
# ff_meat,ff_rice,ff_vegetable: 0.3
# ff_rice,ff_vegetable: 0.09
# ff_bread,ff_meat,ff_seafood,ff_vegetable: 0.29
# ff_noodles/pasta,ff_seafood,ff_soup: 0.61
# ff_egg,ff_rice,ff_vegetable: 0.45
# ff_fried_food,ff_meat,ff_rice,ff_vegetable: 0.99
# ff_meat,ff_rice,ff_soup: 0.95
# ff_fried_food,ff_rice,ff_vegetable: 0.23
# ff_fried_food,ff_meat,ff_rice: 0.29
# ff_bread,ff_noodles/pasta,ff_seafood,ff_soup,ff_vegetable: 0.51
# ff_meat,ff_rice,ff_seafood,ff_vegetable: 0.94
# ff_noodles/pasta,ff_seafood: 0.02
# ff_egg,ff_meat,ff_soup,ff_vegetable: 0.95
# ff_dumpling: 0.73
# ff_fried_food,ff_seafood,ff_vegetable: 0.92
# ff_fried_food,ff_vegetable: 0.89
# ff_egg,ff_soup: 0.4
# ff_egg,ff_meat,ff_rice,ff_vegetable: 0.43
# ff_bread,ff_egg,ff_soup,ff_vegetable: 0.14
# ff_bread,ff_fried_food,ff_meat,ff_rice,ff_vegetable: 0.27
# ff_noodles/pasta,ff_seafood,ff_soup,ff_vegetable: 0.91
# ff_fried_food,ff_seafood: 0.64
# ff_bread,ff_rice: 0.36
# ff_bread,ff_soup,ff_vegetable: 0.12
# ff_bread,ff_fried_food,ff_vegetable: 0.07
# ff_dumpling,ff_seafood: 0.35
# ff_egg,ff_meat,ff_noodles/pasta: 0.9
# ff_fried_food,ff_soup,ff_vegetable: 0.17
# ff_meat,ff_vegetable: 0.86
# ff_meat,ff_seafood,ff_soup,ff_vegetable: 0.98
# ff_fried_food,ff_noodles/pasta,ff_soup: 0.52
# ff_egg,ff_meat,ff_soup: 0.33
# ff_bread,ff_egg,ff_meat: 0.76
# ff_bread,ff_meat,ff_noodles/pasta,ff_vegetable: 0.34
# ff_egg,ff_fried_food,ff_rice: 0.56
# ff_bread,ff_seafood,ff_soup,ff_vegetable: 0.8
# ff_rice: 0.05
# ff_bread,ff_egg,ff_vegetable: 0.99
# ff_bread,ff_noodles/pasta: 0.06
# ff_bread,ff_fried_food,ff_seafood: 0.11
# ff_fried_food: 0.59
# ff_dumpling,ff_egg,ff_vegetable: 0.61
# ff_bread,ff_egg,ff_fried_food,ff_vegetable: 0.75
# ff_dumpling,ff_fried_food,ff_vegetable: 0.61
# ff_dumpling,ff_meat,ff_soup: 0.96
# ff_bread,ff_dumpling: 0.25
# ff_bread,ff_meat,ff_rice,ff_soup: 0.84
# ff_fried_food,ff_noodles/pasta,ff_seafood: 0.15
# ff_noodles/pasta,ff_rice,ff_seafood,ff_vegetable: 0.85
# ff_egg,ff_noodles/pasta,ff_vegetable: 0.64
# ff_bread,ff_noodles/pasta,ff_seafood,ff_vegetable: 0.02
# ff_seafood,ff_vegetable: 0.75
# ff_egg,ff_rice: 0.15
# ff_dumpling,ff_meat,ff_noodles/pasta,ff_vegetable: 0.1
# ff_dumpling,ff_seafood,ff_soup: 0.09
# ff_bread,ff_noodles/pasta,ff_vegetable: 0.39
# ff_meat,ff_soup: 0.33
# ff_bread,ff_egg,ff_seafood,ff_vegetable: 0.04
# ff_rice,ff_soup: 0.81
# ff_bread,ff_egg,ff_fried_food,ff_meat: 0.1
# ff_bread,ff_fried_food,ff_soup,ff_vegetable: 0.56
# ff_egg,ff_noodles/pasta,ff_soup,ff_vegetable: 0.71
# ff_bread,ff_vegetable: 0.78
# ff_fried_food,ff_noodles/pasta,ff_vegetable: 0.16
# ff_noodles/pasta,ff_rice,ff_seafood: 0.32
# ff_egg,ff_vegetable: 0.16
# ff_egg,ff_meat: 0.37
# ff_egg,ff_meat,ff_rice,ff_soup: 0.94
# ff_egg,ff_soup,ff_vegetable: 0.11
# ff_meat,ff_rice,ff_soup,ff_vegetable: 0.88
# ff_fried_food,ff_meat,ff_noodles/pasta,ff_soup,ff_vegetable: 0.27
# ff_dumpling,ff_meat: 0.91
# ff_dumpling,ff_soup,ff_vegetable: 0.15
# ff_fried_food,ff_meat,ff_noodles/pasta,ff_seafood,ff_vegetable: 0.11
# ff_noodles/pasta: 0.29
# ff_egg,ff_meat,ff_noodles/pasta,ff_vegetable: 0.14
# ff_noodles/pasta,ff_rice,ff_vegetable: 0.01
# ff_vegetable: 0.99
# ff_meat,ff_rice: 0.44
# ff_dumpling,ff_noodles/pasta: 0.63
# ff_egg,ff_meat,ff_vegetable: 0.23
# ff_fried_food,ff_meat,ff_noodles/pasta,ff_rice,ff_vegetable: 0.04
# ff_bread,ff_meat,ff_rice: 0.24
# ff_rice,ff_soup,ff_vegetable: 0.13
# ff_bread,ff_egg,ff_meat,ff_vegetable: 0.83
# ff_bread,ff_fried_food,ff_meat,ff_vegetable: 0.82
# ff_bread,ff_meat,ff_noodles/pasta: 0.5
# ff_fried_food,ff_meat: 0.11
# ff_dumpling,ff_seafood,ff_vegetable: 0.08
# ff_meat,ff_noodles/pasta,ff_seafood,ff_vegetable: 0.33
# ff_egg,ff_meat,ff_noodles/pasta,ff_soup: 0.34
# ff_bread,ff_egg,ff_meat,ff_rice,ff_vegetable: 0.9
# ff_bread,ff_noodles/pasta,ff_soup,ff_vegetable: 0.06
# ff_bread,ff_soup: 0.53
# ff_seafood: 0.22
# ff_bread,ff_meat: 0.73
# ff_bread,ff_meat,ff_noodles/pasta,ff_seafood: 0.98
# ff_bread,ff_rice,ff_seafood,ff_vegetable: 0.1
# ff_soup: 0.26
# ff_bread,ff_meat,ff_rice,ff_soup,ff_vegetable: 0.05
# ff_egg,ff_rice,ff_soup,ff_vegetable: 0.18
# ff_noodles/pasta,ff_soup,ff_vegetable: 0.99
# ff_bread,ff_egg,ff_rice: 0.62
# ff_egg,ff_noodles/pasta: 0.85
# ff_bread,ff_meat,ff_soup: 0.56
# ff_seafood,ff_soup: 0.06
# ff_meat,ff_noodles/pasta,ff_seafood: 0.97
# ff_bread,ff_dumpling,ff_meat: 0.47
# ff_meat,ff_noodles/pasta: 0.02
# ff_bread,ff_rice,ff_vegetable: 0.18
# ff_bread,ff_egg,ff_seafood: 0.98
# ff_rice,ff_seafood: 0.93
# ff_noodles/pasta,ff_soup: 0.08
# ff_bread,ff_fried_food,ff_seafood,ff_vegetable: 0.36
# ff_egg,ff_fried_food,ff_meat: 0.1
# ff_egg,ff_fried_food: 0.05
# ff_bread,ff_seafood,ff_vegetable: 0.36
# ff_meat,ff_soup,ff_vegetable: 0.66
# ff_egg,ff_rice,ff_soup: 0.11
# ff_bread,ff_fried_food: 0.72
# ff_meat,ff_rice,ff_seafood: 0.13
# ff_egg,ff_noodles/pasta,ff_seafood: 0.84
# ff_meat,ff_noodles/pasta,ff_vegetable: 0.92
# ff_bread,ff_dumpling,ff_vegetable: 0.6
# ff_bread,ff_egg,ff_rice,ff_vegetable: 0.9
# ff_fried_food,ff_noodles/pasta: 0.73
# ff_egg,ff_meat,ff_rice: 0.71
# ff_fried_food,ff_meat,ff_noodles/pasta,ff_vegetable: 0.19
# ff_noodles/pasta,ff_seafood,ff_vegetable: 0.5
# ff_egg,ff_meat,ff_noodles/pasta,ff_soup,ff_vegetable: 0.99
# ff_fried_food,ff_rice,ff_seafood: 0.23
# ff_bread,ff_meat,ff_soup,ff_vegetable: 0.92
# ff_rice,ff_seafood,ff_vegetable: 0.31
# ff_fried_food,ff_noodles/pasta,ff_seafood,ff_soup: 0.02
# ff_noodles/pasta,ff_vegetable: 0.05
# ff_seafood,ff_soup,ff_vegetable: 0.38
# ff_bread,ff_meat,ff_seafood: 0.86
# ff_meat,ff_seafood,ff_vegetable: 0.03
# ff_fried_food,ff_rice: 0.21
# ff_bread,ff_noodles/pasta,ff_seafood: 0.18
# ff_meat,ff_noodles/pasta,ff_soup,ff_vegetable: 0.14
# ff_egg,ff_seafood: 0.02
# ff_noodles/pasta,ff_rice: 0.86
# ff_egg,ff_fried_food,ff_meat,ff_vegetable: 0.87
# ff_dumpling,ff_soup: 0.65
# ff_fried_food,ff_meat,ff_soup: 0.05
# ff_fried_food,ff_noodles/pasta,ff_soup,ff_vegetable: 0.4
# ff_bread,ff_egg: 0.28
# ff_soup,ff_vegetable: 0.53
# ff_egg,ff_noodles/pasta,ff_soup: 0.85
# ff_bread,ff_seafood: 0.04
# ff_dumpling,ff_meat,ff_vegetable: 0.07
# ff_egg,ff_rice,ff_seafood: 0.89
# ff_bread,ff_egg,ff_fried_food,ff_meat,ff_vegetable: 0.27
# ff_bread,ff_fried_food,ff_meat: 0.32
# ff_meat,ff_noodles/pasta,ff_rice,ff_vegetable: 0.16
# ff_bread,ff_seafood,ff_soup: 0.84
# ff_egg,ff_fried_food,ff_seafood: 0.22
# ff_meat,ff_noodles/pasta,ff_soup: 0.74
# ff_fried_food,ff_meat,ff_noodles/pasta: 0.98
# ff_dumpling,ff_vegetable: 0.62
# ff_bread,ff_meat,ff_rice,ff_vegetable: 0.93
# ff_fried_food,ff_meat,ff_vegetable: 0.24
# ff_egg,ff_rice,ff_seafood,ff_vegetable: 0.99
# ff_bread: 0.96
# ff_meat,ff_seafood,ff_soup: 0.2
# ff_meat,ff_seafood: 0.68
# ff_meat: 0.49
# : 0.87
